# %%
import numpy as np
import math as math
import matplotlib.pyplot as plt

# %% [markdown]
# # アーランB式 (２つの関数を定義)

# %%
#Erlang B式 式をそのまま使ったバージョン
def ErlangB(E,c):
    a = 0
    if E == 0:
        return 0
    for i in range(c+1):
        a += E**i/math.factorial(i)
    return E**c/(math.factorial(c)*a)
            
    
#Erlang B式 漸化式を使ったバージョン
def ErlangBRecur(E,c):
    B = 1
    if E == 0:
        return 0
    for j in range(c+1):
        B= B*E/(j+B*E)
    return B

# %%
error = -1
E_m = 0
c_m = 0
for E in range(120):
    for c in range(120):
        if error < abs(ErlangB(E,c)-ErlangBRecur(E,c)):
            error = abs(ErlangB(E,c)-ErlangBRecur(E,c))
            E_m = E
            c_m = c
print("Erlang B式の値は", ErlangB(E_m, c_m))
print("Erlang B式の値は", ErlangBRecur(E_m, c_m))
print("最大誤差は", error)
print("E:", E_m, "c:", c_m)
# Out:
# Erlang B式の値は 0.8240174505364161
# Erlang B式の値は 0.8240174505364157
# 最大誤差は 3.3306690738754696e-16
# E: 67 c: 12

# %% [markdown]
# # テスト出力

# %%
#Erlang B式 式をそのまま使ったバージョン
print(ErlangB(80,30))#ErlangB(E,c)
# Out:
# 0.6320693461561349

# %%
#Erlang B式 漸化式を使ったバージョン
print(ErlangBRecur(80,300))#ErlangBRecur(E,c)
# Out:
# 4.9846480724814805e-79

# %% [markdown]
# # グラフ出力

# %%
######穴埋め########
c1 = 1
c2 = 2
c3 = 3
c4 = 4
c5 = 5
X = np.arange(1,50,1)#ｘ軸：np.arange(a,b,c)は[a,b)をc刻みでプロットするという意味　←各自必要に応じて変更する
######穴埋め########





#ｘ軸、y軸用のリストを用意
Y1 = list()#空のリスト(後でx軸の値に応じて代入)
Y2 = list()#空のリスト(後でx軸の値に応じて代入)


clist = [c1,c2,c3,c4,c5]
colorlist = ["k","b","y","c","r"]


#リストにx**2の値を格納
for i in range(len(clist)):
    for x in X:
        Y1.append(ErlangB(x,clist[i]))
    plt.plot(X,Y1,label= "ErlangB c="+str(clist[i]),linestyle = "solid",color=colorlist[i])
    Y1 = list()
for i in range(len(clist)):
    for x in X:
        Y2.append(ErlangBRecur(x,clist[i]))
    plt.plot(X,Y2,label= "ErlangBRecur c="+str(clist[i]),linestyle = "None",marker="*",color=colorlist[i])
    Y2 = list()



plt.xlabel("$E$",fontsize=15)#x軸
plt.ylabel("Blocking Probability",fontsize=15)#y軸
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,))#凡例の出力(labelを記載しない場合は削除)
plt.savefig('example1.pdf')#グラフを保存

# %%
######穴埋め########
E1 = 1
E2 = 2
E3 = 3
E4 = 4
E5 = 5
X = np.arange(1,50,1)#ｘ軸：np.arange(a,b,c)は[a,b)をc刻みでプロットするという意味　←各自必要に応じて変更する
######穴埋め########

#ｘ軸、y軸用のリストを用意
Y1 = list()#空のリスト(後でx軸の値に応じて代入)
Y2 = list()#空のリスト(後でx軸の値に応じて代入)


Elist = [E1,E2,E3,E4,E5]
colorlist = ["k","b","y","c","r"]


#リストにx**2の値を格納
for i in range(len(clist)):
    for x in X:
        Y1.append(ErlangB(Elist[i],x))
    plt.plot(X,Y1,label= "ErlangB E="+str(Elist[i]),linestyle = "solid",color=colorlist[i])
    Y1 = list()
for i in range(len(clist)):
    for x in X:
        Y2.append(ErlangBRecur(Elist[i],x))
    plt.plot(X,Y2,label= "ErlangBRecur E="+str(Elist[i]),linestyle = "None",marker="*",color=colorlist[i])
    Y2 = list()



plt.xlabel("Number of channels $(c)$",fontsize=15)#x軸
plt.ylabel("Blocking Probability",fontsize=15)#y軸
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,))#凡例の出力(labelを記載しない場合は削除)
plt.savefig('example2.pdf')#グラフを保存

# %%
######穴埋め########
E1 = 10
E2 = 20
E3 = 30
E4 = 40
E5 = 50
X = np.arange(1,50,1)#ｘ軸：np.arange(a,b,c)は[a,b)をc刻みでプロットするという意味　←各自必要に応じて変更する
######穴埋め########

#ｘ軸、y軸用のリストを用意
Y1 = list()#空のリスト(後でx軸の値に応じて代入)
Y2 = list()#空のリスト(後でx軸の値に応じて代入)


Elist = [E1,E2,E3,E4,E5]
colorlist = ["k","b","y","c","r"]


#リストにx**2の値を格納
for i in range(len(clist)):
    for x in X:
        Y1.append(ErlangB(Elist[i],x))
    plt.plot(X,Y1,label= "ErlangB E="+str(Elist[i]),linestyle = "solid",color=colorlist[i])
    Y1 = list()
for i in range(len(clist)):
    for x in X:
        Y2.append(ErlangBRecur(Elist[i],x))
    plt.plot(X,Y2,label= "ErlangBRecur E="+str(Elist[i]),linestyle = "None",marker="*",color=colorlist[i])
    Y2 = list()



plt.xlabel("Number of channels $(c)$",fontsize=15)#x軸
plt.ylabel("Blocking Probability",fontsize=15)#y軸
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,))#凡例の出力(labelを記載しない場合は削除)
plt.savefig('example2.pdf')#グラフを保存

# %%
E = 50
X = np.arange(1,18,1,dtype=np.int64)#ｘ軸：np.arange(a,b,c)は[a,b)をc刻みでプロットするという意味　←各自必要に応じて変更する
Y1 = list()#空のリスト(後でx軸の値に応じて代入)
for x in X:
    Y1.append(ErlangB(E,x))
plt.plot(X,Y1,label= "ErlangB E="+str(E),linestyle = "solid",color="k")

plt.xlabel("$E$",fontsize=15)#x軸
plt.ylabel("Blocking Probability",fontsize=15)#y軸
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,))#凡例の出力(labelを記載しない場合は削除)
plt.savefig("overflow.png")#グラフを保存

# %%
######穴埋め########
E1 = 40
E2 = 50
X = np.arange(1,20,1)#ｘ軸：np.arange(a,b,c)は[a,b)をc刻みでプロットするという意味　←各自必要に応じて変更する
######穴埋め########

#ｘ軸、y軸用のリストを用意
Y1 = list()#空のリスト(後でx軸の値に応じて代入)
Y2 = list()#空のリスト(後でx軸の値に応じて代入)


Elist = [E1,E2]
colorlist = ["k","b"]


#リストにx**2の値を格納
for i in range(len(Elist)):
    for x in X:
        temp = ErlangBRecur(Elist[i],x)
        Y1.append(temp)
    plt.plot(X,Y1,label= "ErlangB E="+str(Elist[i]),linestyle = "solid",color=colorlist[i])
    Y1 = list()



plt.xlabel("Number of channels $(c)$",fontsize=15)#x軸
plt.ylabel("Blocking Probability",fontsize=15)#y軸
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,))#凡例の出力(labelを記載しない場合は削除)
plt.savefig('example2.pdf')#グラフを保存

# %%
ErlangB(10,10)
# Out:
# 0.21458234310734733

# %%
ErlangB(10,15)
# Out:
# 0.03649694547237079

# %%
ErlangB(20,15)
# Out:
# 0.3299969274185329

# %%
ErlangB(20,20)
# Out:
# 0.15889196154197152

# %%
ans = 0
while True:
    ans += 1
    if ErlangBRecur(50,ans) < 0.001:
        break
print(ans)
# Out:
# 71

# %%
######穴埋め########
c1 = 1
X = np.logspace(-10, -1, num=9)
######穴埋め########





#ｘ軸、y軸用のリストを用意
Y1 = list()#空のリスト(後でx軸の値に応じて代入)
Y2 = list()#空のリスト(後でx軸の値に応じて代入)



colorlist = ["r","b"]


#リストにx**2の値を格納
for x in X:
    ans = 0
    while True:
        ans += 1
        if ErlangBRecur(10,ans) < x:
            break
    Y1.append(ans)
plt.plot(X,Y1,label= "Optional server number E = 10",linestyle = "None",marker = "*",color=colorlist[0])
Y1 = list()

for x in X:
    ans = 0
    while True:
        ans += 1
        if ErlangBRecur(20,ans) < x:
            break
    Y2.append(ans)
plt.plot(X,Y2,label= "Optional server number E = 20",linestyle = "None",marker="*",color=colorlist[1])
Y2 = list()


plt.xscale("log")#x軸を対数表示
plt.xlabel("Blocking Probability",fontsize=15)#x軸
plt.ylabel("Optional number of servers",fontsize=15)#y軸
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,))#凡例の出力(labelを記載しない場合は削除)
plt.savefig('page44.png',bbox_inches='tight')#グラフを保存

# %%
######穴埋め########
c1 = 5
c2 = 10
c3 = 15
c4 = 20
c5 = 25
X = np.arange(0,100,1)#ｘ軸：np.arange(a,b,c)は[a,b)をc刻みでプロットするという意味　←各自必要に応じて変更する
######穴埋め########


#ｘ軸、y軸用のリストを用意
Y1 = list()#空のリスト(後でx軸の値に応じて代入)
Y2 = list()#空のリスト(後でx軸の値に応じて代入)


clist = [c1,c2,c3,c4,c5]
colorlist = ["k","b","y","c","r"]


#リストにx**2の値を格納
for i in range(len(clist)):
    for x in X:
        Y1.append(ErlangBRecur(x,clist[i]))
    plt.plot(X,Y1,label= "c="+str(clist[i]),linestyle = "solid",color=colorlist[i])
    Y1 = list()



plt.xlabel("$E$(Erlang)",fontsize=15)#x軸
plt.ylabel("Blocking Probability",fontsize=15)#y軸
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,))#凡例の出力(labelを記載しない場合は削除)
plt.savefig('page42.png',bbox_inches='tight')#グラフを保存

# %%
######穴埋め########
E1 = 1
E2 = 10
E3 = 20
E4 = 50
E5 = 80
E6 = 100
X = np.arange(0,100,1)#ｘ軸：np.arange(a,b,c)は[a,b)をc刻みでプロットするという意味　←各自必要に応じて変更する
######穴埋め########


#ｘ軸、y軸用のリストを用意
Y1 = list()#空のリスト(後でx軸の値に応じて代入)
Y2 = list()#空のリスト(後でx軸の値に応じて代入)


Elist = [E1,E2,E3,E4,E5,E6]
colorlist = ["k","b","y","c","r","g"]


#リストにx**2の値を格納
for i in range(len(Elist)):
    for x in X:
        Y1.append(ErlangBRecur(Elist[i],x))
    plt.plot(X,Y1,label= "c="+str(Elist[i]),linestyle = "solid",color=colorlist[i])
    Y1 = list()



plt.xlabel("Number of servers",fontsize=15)#x軸
plt.ylabel("Blocking Probability",fontsize=15)#y軸
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1.0,))#凡例の出力(labelを記載しない場合は削除)
plt.savefig('page43.png',bbox_inches='tight')#グラフを保存
